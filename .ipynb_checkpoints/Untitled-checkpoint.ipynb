# %%
import pandas as pd

orcamento = pd.read_excel('orcamento.xlsx')
venda = pd.read_excel('venda.xlsx')
display(venda)
display(orcamento)
venda["Item MRN"] = venda["Item MRN"].fillna(0.0).astype(int)
array = venda["Item MRN"].to_numpy()
a2 = []
for a in array:
    list = str(a)
    a2.append(list)
display(a2)
o = orcamento.loc[orcamento['Item MRN'].isin(a2)]
display(o)
o.to_excel('orcamento-final.xlsx')
# Out:
#        Seq  Item MRN Unid Forn  \
# 0      1.0   85862.0        PÇ
# 1      2.0   85863.0        PÇ
# 2      3.0   85869.0        PÇ
# 3      4.0   85893.0        PÇ
# 4      5.0   85895.0        PÇ
# ..     ...       ...       ...
# 578  579.0   44163.0        PÇ
# 579  580.0   57892.0        PÇ
# 580  581.0   64859.0        PÇ
# 581  582.0   47528.0        PC
# 582    NaN       NaN       NaN
#
#                                              Narrativa  Unitario      Total  \
# 0    ANEL; APLICACAO: EQUIPAMENTO CATERPILLAR; 7M84...      1.14      29.64
# 1    ANEL; APLICACAO: EQUIPAMENTO CATERPILLAR; 3J19...      0.95     208.05
# 2      RETENTOR; APLICACAO: TRATOR ESTEIRA; 3J7354 GHT      0.76     156.56
# 3      RETENTOR; APLICACAO: TRATOR ESTEIRA; 3D2824 GHT      0.70     106.40
# 4      RETENTOR; APLICACAO: TRATOR ESTEIRA; 6L9965 GHT      2.00      26.00
# ..                                                 ...       ...        ...
# ...
